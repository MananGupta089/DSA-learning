# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("company.csv")
# Out:
#    emp_id    name department   salary  age  experience       city
# 0       1    Aman      Sales  35000.0   24           2      Delhi
# 1       2   Priya         IT  55000.0   28           5     Mumbai
# 2       3   Rahul      Sales  32000.0   23           1      Delhi
# 3       4   Sneha         IT  60000.0   30           6  Bangalore
# 4       5   Karan         HR  40000.0   26           3      Delhi
# 5       6    Riya      Sales  38000.0   25           2     Mumbai
# 6       7   Arjun         HR  42000.0   29           4        NaN
# 7       8   Pooja         IT  58000.0   27           5  Bangalore
# 8       9  Vikram      Sales      NaN   24           2      Delhi
# 9      10    Neha         HR  45000.0   31           6     Mumbai

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined
